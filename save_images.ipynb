# %%
import os
import io
from PIL import Image

# %%
from datasets import load_dataset
dataset = load_dataset("mychen76/invoices-and-receipts_ocr_v1", split = "train")

# %%
for i in list(range(0,200)) + list(range(425,625)):
    # print(f"Image{i:04d}")
    img = dataset['image'][i]
    img.save(f'aws-to-paddle-dataset\images\image_inv_{i:04d}.png')
